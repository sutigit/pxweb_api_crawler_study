# %% [markdown]
# ## URL structure
#
# example url: 'https://pxdata.stat.fi:443/PxWeb/api/v1/fi/Kuntien_avainluvut/uusin/kuntien_avainluvut_aikasarja.px'
#
# structure:
# <ul>
#     <li>
#         base: 'https://pxdata.stat.fi:443/PxWeb/api/v1'
#     </li>
#     <li>
#         language
#     </li>
#     <li>
#         dbid
#     </li>
#     <li>
#         id
#     </li>
#     <li>
#         id2 (optional)
#     </li>
#     <li>
#         id3 (optional)
#     </li>
# </ul>
#
# endpoint structure: base + language + dbid + id + (id2) + (id3)

# %% [markdown]
# ### - Define objects
# - Class MyUrl
# - Class Printer
# - Class PxWeb

# %%
import requests
from pprint import pprint

class MyUrl:
    def __init__(self, base_url):
        self.url = {
            'base': base_url.rstrip('/'),
            'language': None,
            'dbid': None,
            'ids': [],
        }
        
        self.endpoint_found = False
    
    def get_current(self):
        current_url = ''
        
        for key, value in self.url.items():
            if key == 'ids' and len(value) > 0:
                for id in value:
                    current_url += f'{id}/'
                    
            elif value:
                current_url += f'{value}/'
            
        return current_url
        
    def set_language(self, language):
        self.url['language'] = language
        
    def get_language(self):
        return self.url['language']
    
    def set_dbid(self, dbid):
        self.url['dbid'] = dbid
        
    def get_dbid(self):
        return self.url['dbid']
    
    def add_id(self, id):
        self.url['ids'].append(id)
        
        if id.endswith('.px'):
            self.endpoint_found = True
        
    def get_ids(self):
        return self.url['ids']
    
    def get_last_id(self):
        return self.url['ids'][-1]
    
    
class Printer:
    def __init__(self, endpoint):
        self.endpoint = endpoint
        
    def print_chosen(self, item, idx):
        self.print_current_url(self.endpoint.get_current())
        
        print("CHOSEN INDEX:", idx)
        print('-' * 40)
        
        if self.endpoint.endpoint_found:
            print('ENDPOINT FOUND!')
            
        print(f'{idx}: {item}')
        
    def print_options(self, options):
        self.print_current_url(self.endpoint.get_current())
        
        print("OPTIONS")
        print('-' * 40)
        for idx, option in enumerate(options):
            print(f'{idx}: {option}')
        
    def print_data(self, data):
        self.print_current_url(self.endpoint.get_current())
        
        print("DATA")
        print('-' * 40)
        pprint(data)
        
    def print_current_url(self, url):
        print("CURRENT URL:", url)
        print('-' * 40)
        
            
class PxWeb:
    def fetch(self, url):
        response = requests.get(url)
        if response.status_code == 200:    
            return response.json()
        else:
            print('Error retrieving data')
            
    def post(self, url, data):
        response = requests.post(url, json=data)
        if response.status_code == 200:    
            return response.json()
        else:
            print('Error retrieving data')
            
            
# Initialize the class   
endpoint = MyUrl('https://pxdata.stat.fi:443/PxWeb/api/v1/')
printer = Printer(endpoint)
pw = PxWeb()

# %% [markdown]
# ### - Choose language
# - url.language = lang

# %%
languages = ['fi', 'en']
idx = 0

endpoint.set_language(languages[idx])
printer.print_chosen(languages[idx], idx)
# Out:
# CURRENT URL: https://pxdata.stat.fi:443/PxWeb/api/v1/fi/
# ----------------------------------------
# CHOSEN INDEX: 0
# ----------------------------------------
# 0: fi

# %% [markdown]
# ### Inspect endpoint
# - fetch URL: base + language

# %%
options = pw.fetch(endpoint.get_current())
printer.print_options(options)
# Out:
# CURRENT URL: https://pxdata.stat.fi:443/PxWeb/api/v1/fi/
# ----------------------------------------
# OPTIONS
# ----------------------------------------
# 0: {'dbid': 'Check', 'text': 'Check'}
# 1: {'dbid': 'Hyvinvointialueet', 'text': 'Hyvinvointialueet'}
# 2: {'dbid': 'Kokeelliset_tilastot', 'text': 'Kokeelliset_tilastot'}
# 3: {'dbid': 'Kuntien_avainluvut', 'text': 'Kuntien_avainluvut'}
# 4: {'dbid': 'Kuntien_talous_ja_toiminta', 'text': 'Kuntien_talous_ja_toiminta'}
# 5: {'dbid': 'Maahanmuuttajat_ja_kotoutuminen', 'text': 'Maahanmuuttajat_ja_kotoutuminen'}
# 6: {'dbid': 'Muuttaneiden_taustatiedot', 'text': 'Muuttaneiden_taustatiedot'}
# 7: {'dbid': 'Postinumeroalueittainen_avoin_tieto', 'text': 'Postinumeroalueittainen_avoin_tieto'}
# 8: {'dbid': 'SDG', 'text': 'SDG'}
# 9: {'dbid': 'StatFin', 'text': 'StatFin'}
# 10: {'dbid': 'StatFin_Passiivi', 'text': 'StatFin_Passiivi'}
# 11: {'dbid': 'Toimipaikkalaskuri', 'text': 'Toimipaikkalaskuri'}
# 12: {'dbid': 'ymp', 'text': 'ymp'}

# %% [markdown]
# ### - Choose dbid
# - pre-chosen index: 3
# - title: Kuntien avainluvut

# %%
# Choose index
idx = 3 # Kuntien avainluvut: keep this index

endpoint.set_dbid(options[idx]['dbid'])
printer.print_chosen(options[idx]['text'], idx)
# Out:
# CURRENT URL: https://pxdata.stat.fi:443/PxWeb/api/v1/fi/Kuntien_avainluvut/
# ----------------------------------------
# CHOSEN INDEX: 3
# ----------------------------------------
# 3: Kuntien_avainluvut

# %% [markdown]
# ### - Inspect dbid endpoint

# %%
options = pw.fetch(endpoint.get_current())
printer.print_options(options)
# Out:
# CURRENT URL: https://pxdata.stat.fi:443/PxWeb/api/v1/fi/Kuntien_avainluvut/
# ----------------------------------------
# OPTIONS
# ----------------------------------------
# 0: {'id': '2015', 'type': 'l', 'text': '2015 aluejaolla'}
# 1: {'id': '2016', 'type': 'l', 'text': '2016 aluejaolla'}
# 2: {'id': '2019', 'type': 'l', 'text': '2019 aluejaolla'}
# 3: {'id': '2020', 'type': 'l', 'text': '2020 aluejaolla'}
# 4: {'id': '2021', 'type': 'l', 'text': '2021 aluejaolla'}
# 5: {'id': '2023', 'type': 'l', 'text': '2023 aluejaolla'}
# 6: {'id': 'uusin', 'type': 'l', 'text': 'Uusimmalla aluejaolla'}

# %% [markdown]
# ### - Choose id
# - pre-chosen index: 6
# - title: uusin

# %%
idx = 6 # uusin: keep this index

endpoint.add_id(options[idx]['id'])
printer.print_chosen(options[idx]['id'], idx)
# Out:
# CURRENT URL: https://pxdata.stat.fi:443/PxWeb/api/v1/fi/Kuntien_avainluvut/uusin/
# ----------------------------------------
# CHOSEN INDEX: 6
# ----------------------------------------
# 6: uusin

# %% [markdown]
# ### - Inspect id endpoint

# %%
if endpoint.endpoint_found:
    data = pw.fetch(endpoint.get_current())
    printer.print_data(data)
else:
    options = pw.fetch(endpoint.get_current())
    printer.print_options(options)
# Out:
# CURRENT URL: https://pxdata.stat.fi:443/PxWeb/api/v1/fi/Kuntien_avainluvut/uusin/
# ----------------------------------------
# OPTIONS
# ----------------------------------------
# 0: {'id': '142h.px', 'type': 't', 'text': '142h -- Alueaikasarjat, 1987-2023', 'updated': '2024-09-17T15:45:46'}
# 1: {'id': 'kuntien_avainluvut_aikasarja.px', 'type': 't', 'text': 'Kuntien avainluvut 1987-2023', 'updated': '2024-09-17T15:42:36'}
# 2: {'id': 'kuntien_avainluvut_viimeisin.px', 'type': 't', 'text': 'Kuntien avainluvut', 'updated': '2024-09-17T15:41:41'}

# %% [markdown]
# ### - Choose id

# %%
idx = 0

endpoint.add_id(options[idx]['id'])
printer.print_chosen(options[idx]['id'], idx)
# Out:
# CURRENT URL: https://pxdata.stat.fi:443/PxWeb/api/v1/fi/Kuntien_avainluvut/uusin/142h.px/
# ----------------------------------------
# CHOSEN INDEX: 0
# ----------------------------------------
# ENDPOINT FOUND!
# 0: 142h.px

# %% [markdown]
# ### - Inspect endpoint

# %%
if endpoint.endpoint_found:
    data = pw.fetch(endpoint.get_current())
    printer.print_data(data)
else:
    options = pw.fetch(endpoint.get_current())
    printer.print_options(options)
# Out:
# CURRENT URL: https://pxdata.stat.fi:443/PxWeb/api/v1/fi/Kuntien_avainluvut/uusin/142h.px/
# ----------------------------------------
# DATA
# ----------------------------------------
# {'title': 'Alueaikasarjat muuttujina Alue, Tiedot ja Vuosi',
#  'variables': [{'code': 'Alue',
#                 'elimination': True,
#                 'map': 'Alue 2023',
#                 'text': 'Alue',
#                 'valueTexts': ['KOKO MAA',
#                                'Akaa',
#                                'Alajärvi',
#                                'Alavieska',
#                                'Alavus',
#                                'Asikkala',
#                                'Askola',
#                                'Aura',
#                                'Brändö',
#                                'Eckerö',
#                                'Enonkoski',
#                                'Enontekiö',
#                                'Espoo',
#                                'Eura',
#                                'Eurajoki',
#                                'Evijärvi',
#                                'Finström',
#                                'Forssa',
#                                'Föglö',
#                                'Geta',
#                                'Haapajärvi',
#                                'Haapavesi',
#                                'Hailuoto',
#                                'Halsua',
#                                'Hamina',
#                                'Hammarland',
#                                'Hankasalmi',
#                                'Hanko',
#                                'Harjavalta',
#                                'Hartola',
#                                'Hattula',
#                                'Hausjärvi',
#                                'Heinola',
#                                'Heinävesi',
#                                'Helsinki',
#                                'Hirvensalmi',
#                                'Hollola',
#                                'Huittinen',
#                                'Humppila',
#                                'Hyrynsalmi',
#                                'Hyvinkää',
#                                'Hämeenkyrö',
#                                'Hämeenlinna',
#                                'Ii',
#                                'Iisalmi',
#                                'Iitti',
#                                'Ikaalinen',
#                                'Ilmajoki',
#                                'Ilomantsi',
#                                'Imatra',
#                                'Inari',
#                                'Inkoo',
#                                'Isojoki',
#                                'Isokyrö',
#                                'Janakkala',
#                                'Joensuu',
#                                'Jokioinen',
#                                'Jomala',
#                                'Joroinen',
#                                'Joutsa',
#                                'Juuka',
#                                'Juupajoki',
#                                'Juva',
#                                'Jyväskylä',
#                                'Jämijärvi',
#                                'Jämsä',
#                                'Järvenpää',
#                                'Kaarina',
#                                'Kaavi',
#                                'Kajaani',
#                                'Kalajoki',
#                                'Kangasala',
#                                'Kangasniemi',
#                                'Kankaanpää',
#                                'Kannonkoski',
#                                'Kannus',
#                                'Karijoki',
#                                'Karkkila',
#                                'Karstula',
#                                'Karvia',
#                                'Kaskinen',
#                                'Kauhajoki',
#                                'Kauhava',
#                                'Kauniainen',
#                                'Kaustinen',
#                                'Keitele',
#                                'Kemi',
#                                'Kemijärvi',
#                                'Keminmaa',
#                                'Kemiönsaari',
#                                'Kempele',
#                                'Kerava',
#                                'Keuruu',
#                                'Kihniö',
#                                'Kinnula',
#                                'Kirkkonummi',
#                                'Kitee',
#                                'Kittilä',
#                                'Kiuruvesi',
#                                'Kivijärvi',
#                                'Kokemäki',
#                                'Kokkola',
#                                'Kolari',
#                                'Konnevesi',
#                                'Kontiolahti',
#                                'Korsnäs',
#                                'Koski Tl',
#                                'Kotka',
#                                'Kouvola',
#                                'Kristiinankaupunki',
#                                'Kruunupyy',
#                                'Kuhmo',
#                                'Kuhmoinen',
#                                'Kumlinge',
#                                'Kuopio',
#                                'Kuortane',
#                                'Kurikka',
#                                'Kustavi',
#                                'Kuusamo',
#                                'Kyyjärvi',
#                                'Kärkölä',
#                                'Kärsämäki',
#                                'Kökar',
#                                'Lahti',
#                                'Laihia',
#                                'Laitila',
#                                'Lapinjärvi',
#                                'Lapinlahti',
#                                'Lappajärvi',
#                                'Lappeenranta',
#                                'Lapua',
#                                'Laukaa',
#                                'Lemi',
#                                'Lemland',
#                                'Lempäälä',
#                                'Leppävirta',
#                                'Lestijärvi',
#                                'Lieksa',
#                                'Lieto',
#                                'Liminka',
#                                'Liperi',
#                                'Lohja',
#                                'Loimaa',
#                                'Loppi',
#                                'Loviisa',
#                                'Luhanka',
#                                'Lumijoki',
#                                'Lumparland',
#                                'Luoto',
#                                'Luumäki',
#                                'Maalahti',
#                                'Maarianhamina - Mariehamn',
#                                'Marttila',
#                                'Masku',
#                                'Merijärvi',
#                                'Merikarvia',
#                                'Miehikkälä',
#                                'Mikkeli',
#                                'Muhos',
#                                'Multia',
#                                'Muonio',
#                                'Mustasaari',
#                                'Muurame',
#                                'Mynämäki',
#                                'Myrskylä',
#                                'Mäntsälä',
#                                'Mänttä-Vilppula',
#                                'Mäntyharju',
#                                'Naantali',
#                                'Nakkila',
#                                'Nivala',
#                                'Nokia',
#                                'Nousiainen',
#                                'Nurmes',
#                                'Nurmijärvi',
#                                'Närpiö',
#                                'Orimattila',
#                                'Oripää',
#                                'Orivesi',
#                                'Oulainen',
#                                'Oulu',
#                                'Outokumpu',
#                                'Padasjoki',
#                                'Paimio',
#                                'Paltamo',
#                                'Parainen',
#                                'Parikkala',
#                                'Parkano',
#                                'Pedersören kunta',
#                                'Pelkosenniemi',
#                                'Pello',
#                                'Perho',
#                                'Pertunmaa',
#                                'Petäjävesi',
#                                'Pieksämäki',
#                                'Pielavesi',
#                                'Pietarsaari',
#                                'Pihtipudas',
#                                'Pirkkala',
#                                'Polvijärvi',
#                                'Pomarkku',
#                                'Pori',
#                                'Pornainen',
#                                'Porvoo',
#                                'Posio',
#                                'Pudasjärvi',
#                                'Pukkila',
#                                'Punkalaidun',
#                                'Puolanka',
#                                'Puumala',
#                                'Pyhtää',
#                                'Pyhäjoki',
#                                'Pyhäjärvi',
#                                'Pyhäntä',
#                                'Pyhäranta',
#                                'Pälkäne',
#                                'Pöytyä',
#                                'Raahe',
#                                'Raasepori',
#                                'Raisio',
#                                'Rantasalmi',
#                                'Ranua',
#                                'Rauma',
#                                'Rautalampi',
#                                'Rautavaara',
#                                'Rautjärvi',
#                                'Reisjärvi',
#                                'Riihimäki',
#                                'Ristijärvi',
#                                'Rovaniemi',
#                                'Ruokolahti',
#                                'Ruovesi',
#                                'Rusko',
#                                'Rääkkylä',
#                                'Saarijärvi',
#                                'Salla',
#                                'Salo',
#                                'Saltvik',
#                                'Sastamala',
#                                'Sauvo',
#                                'Savitaipale',
#                                'Savonlinna',
#                                'Savukoski',
#                                'Seinäjoki',
#                                'Sievi',
#                                'Siikainen',
#                                'Siikajoki',
#                                'Siikalatva',
#                                'Siilinjärvi',
#                                'Simo',
#                                'Sipoo',
#                                'Siuntio',
#                                'Sodankylä',
#                                'Soini',
#                                'Somero',
#                                'Sonkajärvi',
#                                'Sotkamo',
#                                'Sottunga',
#                                'Sulkava',
#                                'Sund',
#                                'Suomussalmi',
#                                'Suonenjoki',
#                                'Sysmä',
#                                'Säkylä',
#                                'Taipalsaari',
#                                'Taivalkoski',
#                                'Taivassalo',
#                                'Tammela',
#                                'Tampere',
#                                'Tervo',
#                                'Tervola',
#                                'Teuva',
#                                'Tohmajärvi',
#                                'Toholampi',
#                                'Toivakka',
#                                'Tornio',
#                                'Turku',
#                                'Tuusniemi',
#                                'Tuusula',
#                                'Tyrnävä',
#                                'Ulvila',
#                                'Urjala',
#                                'Utajärvi',
#                                'Utsjoki',
#                                'Uurainen',
#                                'Uusikaarlepyy',
#                                'Uusikaupunki',
#                                'Vaala',
#                                'Vaasa',
#                                'Valkeakoski',
#                                'Vantaa',
#                                'Varkaus',
#                                'Vehmaa',
#                                'Vesanto',
#                                'Vesilahti',
#                                'Veteli',
#                                'Vieremä',
#                                'Vihti',
#                                'Viitasaari',
#                                'Vimpeli',
#                                'Virolahti',
#                                'Virrat',
#                                'Vårdö',
#                                'Vöyri',
#                                'Ylitornio',
#                                'Ylivieska',
#                                'Ylöjärvi',
#                                'Ypäjä',
#                                'Ähtäri',
#                                'Äänekoski',
#                                'MA1 MANNER - SUOMI',
#                                'SA1 Helsinki-Uusimaa',
#                                'SA2 Etelä-Suomi',
#                                'SA3 Länsi-Suomi',
#                                'SA4 Pohjois- ja Itä-Suomi',
#                                'MK01 Uusimaa',
#                                'MK02 Varsinais-Suomi',
#                                'MK04 Satakunta',
#                                'MK05 Kanta-Häme',
#                                'MK06 Pirkanmaa',
#                                'MK07 Päijät-Häme',
#                                'MK08 Kymenlaakso',
#                                'MK09 Etelä-Karjala',
#                                'MK10 Etelä-Savo',
#                                'MK11 Pohjois-Savo',
#                                'MK12 Pohjois-Karjala',
#                                'MK13 Keski-Suomi',
#                                'MK14 Etelä-Pohjanmaa',
#                                'MK15 Pohjanmaa',
#                                'MK16 Keski-Pohjanmaa',
#                                'MK17 Pohjois-Pohjanmaa',
#                                'MK18 Kainuu',
#                                'MK19 Lappi',
#                                'MA2 AHVENANMAA',
#                                'SA5 Ahvenanmaa',
#                                'MK21 Ahvenanmaa',
#                                'HVA01 Itä-Uudenmaan hyvinvointialue',
#                                'HVA02 Keski-Uudenmaan hyvinvointialue',
#                                'HVA03 Länsi-Uudenmaan hyvinvointialue',
#                                'HVA04 Vantaan ja Keravan hyvinvointialue',
#                                'HVA05 Varsinais-Suomen hyvinvointialue',
#                                'HVA06 Satakunnan hyvinvointialue',
#                                'HVA06 Kanta-Hämeen hyvinvointialue',
#                                'HVA08 Pirkanmaan hyvinvointialue',
#                                'HVA09 Päijät-Hämeen hyvinvointialue',
#                                'HVA10 Kymenlaakson hyvinvointialue',
#                                'HVA11 Etelä-Karjalan hyvinvointialue',
#                                'HVA12 Etelä-Savon hyvinvointialue',
#                                'HVA13 Pohjois-Savon hyvinvointialue',
#                                'HVA14 Pohjois-Karjalan hyvinvointialue',
#                                'HVA15 Keski-Suomen hyvinvointialue',
#                                'HVA16 Etelä-Pohjanmaan hyvinvointialue',
#                                'HVA17 Pohjanmaan hyvinvointialue',
#                                'HVA18 Keski-Pohjanmaan hyvinvointialue',
#                                'HVA19 Pohjois-Pohjanmaan hyvinvointialue',
#                                'HVA20 Kainuun hyvinvointialue',
#                                'HVA21 Lapin hyvinvointialue',
#                                'HVA90 Helsingin kaupunki',
#                                'HVA91 Ahvenanmaa',
#                                'SK011 Helsinki',
#                                'SK014 Raasepori',
#                                'SK015 Porvoo',
#                                'SK016 Loviisa',
#                                'SK021 Åboland-Turunmaa',
#                                'SK022 Salo',
#                                'SK023 Turku',
#                                'SK024 Vakka-Suomi',
#                                'SK025 Loimaa',
#                                'SK041 Rauma',
#                                'SK043 Pori',
#                                'SK044 Pohjois-Satakunta',
#                                'SK051 Hämeenlinna',
#                                'SK052 Riihimäki',
#                                'SK053 Forssa',
#                                'SK061 Luoteis-Pirkanmaa',
#                                'SK063 Etelä-Pirkanmaa',
#                                'SK064 Tampere',
#                                'SK068 Lounais-Pirkanmaa',
#                                'SK069 Ylä-Pirkanmaa',
#                                'SK071 Lahti',
#                                'SK081 Kouvola',
#                                'SK082 Kotka-Hamina',
#                                'SK091 Lappeenranta',
#                                'SK093 Imatra',
#                                'SK101 Mikkeli',
#                                'SK103 Savonlinna',
#                                'SK105 Pieksämäki',
#                                'SK111 Ylä-Savo',
#                                'SK112 Kuopio',
#                                'SK113 Koillis-Savo',
#                                'SK114 Varkaus',
#                                'SK115 Sisä-Savo',
#                                'SK122 Joensuu',
#                                'SK124 Keski-Karjala',
#                                'SK125 Pielisen Karjala',
#                                'SK131 Jyväskylä',
#                                'SK132 Joutsa',
#                                'SK133 Keuruu',
#                                'SK134 Jämsä',
#                                'SK135 Äänekoski',
#                                'SK138 Saarijärvi-Viitasaari',
#                                'SK141 Suupohja',
#                                'SK142 Seinäjoki',
#                                'SK144 Kuusiokunnat',
#                                'SK146 Järviseutu',
#                                'SK152 Vaasa',
#                                'SK153 Sydösterbotten',
#                                'SK154 Jakobstadsregionen',
#                                'SK161 Kaustinen',
#                                'SK162 Kokkola',
#                                'SK171 Oulu',
#                                'SK173 Oulunkaari',
#                                'SK174 Raahe',
#                                'SK175 Haapavesi-Siikalatva',
#                                'SK176 Nivala-Haapajärvi',
#                                'SK177 Ylivieska',
#                                'SK178 Koillismaa',
#                                'SK181 Kehys-Kainuu',
#                                'SK182 Kajaani',
#                                'SK191 Rovaniemi',
#                                'SK192 Kemi-Tornio',
#                                'SK193 Torniolaakso',
#                                'SK194 Itä-Lappi',
#                                'SK196 Tunturi-Lappi',
#                                'SK197 Pohjois-Lappi',
#                                'SK211 Mariehamns stad',
#                                'SK212 Ålands landsbygd',
#                                'SK213 Ålands skärgård',
#                                'ELY01 Uudenmaan ELY-keskus',
#                                'ELY02 Varsinais-Suomen ELY-keskus',
#                                'ELY03 Satakunnan ELY-keskus',
#                                'ELY04 Hämeen ELY-keskus',
#                                'ELY05 Pirkanmaan ELY-keskus',
#                                'ELY06 Kaakkois-Suomen ELY-keskus',
#                                'ELY07 Etelä-Savon ELY-keskus',
#                                'ELY08 Pohjois-Savon ELY-keskus',
#                                'ELY09 Pohjois-Karjalan ELY-keskus',
#                                'ELY10 Keski-Suomen ELY-keskus',
#                                'ELY11 Etelä-Pohjanmaan ELY-keskus',
#                                'ELY12 Pohjanmaan ELY-keskus',
#                                'ELY13 Pohjois-Pohjanmaan ELY-keskus',
#                                'ELY14 Kainuun ELY-keskus',
#                                'ELY15 Lapin ELY-keskus',
#                                'ELY16 Ahvenanmaa',
#                                'AVI1 Etelä-Suomen AVI',
#                                'AVI2 Lounais-Suomen AVI',
#                                'AVI3 Itä-Suomen AVI',
#                                'AVI4 Länsi- ja Sisä-Suomen AVI',
#                                'AVI5 Pohjois-Suomen AVI',
#                                'AVI6 Lapin AVI',
#                                'AVI7 Ahvenanmaan valtionvirasto',
#                                'TK1 Kaupunkimaiset kunnat',
#                                'TK2 Taajaan asutut kunnat',
#                                'TK3 Maaseutumaiset kunnat',
#                                'SHP09 Etelä-Karjalan SHP',
#                                'SHP15 Etelä-Pohjanmaan SHP',
#                                'SHP10 Etelä-Savon SHP',
#                                'SHP25 Helsingin ja Uudenmaan SHP',
#                                'SHP11 Itä-Savon SHP',
#                                'SHP19 Kainuun SHP',
#                                'SHP05 Kanta-Hämeen SHP',
#                                'SHP17 Keski-Pohjanmaan SHP',
#                                'SHP14 Keski-Suomen SHP',
#                                'SHP08 Kymenlaakson SHP',
#                                'SHP21 Lapin SHP',
#                                'SHP20 Länsi-Pohjan SHP',
#                                'SHP06 Pirkanmaan SHP',
#                                'SHP12 Pohjois-Karjalan SHP',
#                                'SHP18 Pohjois-Pohjanmaan SHP',
#                                'SHP13 Pohjois-Savon SHP',
#                                'SHP07 Päijät-Hämeen SHP',
#                                'SHP04 Satakunnan SHP',
#                                'SHP16 Vaasan SHP',
#                                'SHP03 Varsinais-Suomen SHP',
#                                'SHP00 Ahvenanmaa',
#                                'VP01 Helsingin vaalipiiri',
#                                'VP02 Uudenmaan vaalipiiri',
#                                'VP03 Varsinais-Suomen vaalipiiri',
#                                'VP04 Satakunnan vaalipiiri',
#                                'VP06 Hämeen vaalipiiri',
#                                'VP07 Pirkanmaan vaalipiiri',
#                                'VP08 Kaakkois-Suomen vaalipiiri',
#                                'VP09 Savo-Karjalan vaalipiiri',
#                                'VP10 Vaasan vaalipiiri',
#                                'VP11 Keski-Suomen vaalipiiri',
#                                'VP12 Oulun vaalipiiri',
#                                'VP13 Lapin vaalipiiri',
#                                'VP05 Ahvenanmaan maakunnan vaalipiiri',
#                                'PL5500 Helsingin poliisilaitos',
#                                'PL5530 Länsi-Uudenmaan poliisilaitos',
#                                'PL5560 Itä-Uudenmaan poliisilaitos',
#                                'PL5590 Hämeen poliisilaitos',
#                                'PL5620 Kaakkois-Suomen poliisilaitos',
#                                'PL5650 Lounais-Suomen poliisilaitos',
#                                'PL5680 Sisä-Suomen poliisilaitos',
#                                'PL5710 Pohjanmaan poliisilaitos',
#                                'PL5740 Itä-Suomen poliisilaitos',
#                                'PL5770 Oulun poliisilaitos',
#                                'PL5800 Lapin poliisilaitos',
#                                'PL5830 Ålands polismyndighet',
#                                'HO1 Helsingin hovioikeus',
#                                'HO2 Turun hovioikeus',
#                                'HO3 Itä-Suomen hovioikeus',
#                                'HO4 Vaasan hovioikeus',
#                                'HO6 Rovaniemen hovioikeus',
#                                'KO706 Helsingin käräjäoikeus',
#                                'KO708 Kanta-Hämeen käräjäoikeus',
#                                'KO713 Pohjois-Karjalan käräjäoikeus',
#                                'KO715 Keski-Suomen käräjäoikeus',
#                                'KO717 Kainuun käräjäoikeus',
#                                'KO725 Kymenlaakson käräjäoikeus',
#                                'KO726 Pohjois-Savon käräjäoikeus',
#                                'KO729 Päijät-Hämeen käräjäoikeus',
#                                'KO730 Lapin käräjäoikeus',
#                                'KO731 Etelä-Karjalan käräjäoikeus',
#                                'KO736 Etelä-Savon käräjäoikeus',
#                                'KO742 Oulun käräjäoikeus',
#                                'KO747 Satakunnan käräjäoikeus',
#                                'KO748 Itä-Uudenmaan käräjäoikeus',
#                                'KO750 Länsi-Uudenmaan käräjäoikeus',
#                                'KO757 Etelä-Pohjanmaan käräjäoikeus',
#                                'KO758 Pirkanmaan käräjäoikeus',
#                                'KO761 Varsinais-Suomen käräjäoikeus',
#                                'KO764 Pohjanmaan käräjäoikeus',
#                                'KO769 Ahvenanmaan käräjäoikeus',
#                                'FI1 MANNER-SUOMI',
#                                'FI19 Länsi-Suomi',
#                                'FI193 Keski-Suomi',
#                                'FI194 Etelä-Pohjanmaa',
#                                'FI195 Pohjanmaa',
#                                'FI196 Satakunta',
#                                'FI197 Pirkanmaa',
#                                'FI1B Helsinki-Uusimaa',
#                                'FI1B1 Helsinki-Uusimaa',
#                                'FI1C Etelä-Suomi',
#                                'FI1C1 Varsinais-Suomi',
#                                'FI1C2 Kanta-Häme',
#                                'FI1C3 Päijät-Häme',
#                                'FI1C4 Kymenlaakso',
#                                'FI1C5 Etelä-Karjala',
#                                'FI1D Pohjois- ja Itä-Suomi',
#                                'FI1D1 Etelä-Savo',
#                                'FI1D2 Pohjois-Savo',
#                                'FI1D3 Pohjois-Karjala',
#                                'FI1D5 Keski-Pohjanmaa',
#                                'FI1D7 Lappi',
#                                'FI1D8 Kainuu',
#                                'FI1D9 Pohjois-Pohjanmaa',
#                                'FI2 ÅLAND',
#                                'FI20 Åland',
#                                'FI200 Åland'],
#                 'values': ['SSS',
#                            'KU020',
#                            'KU005',
#                            'KU009',
#                            'KU010',
#                            'KU016',
#                            'KU018',
#                            'KU019',
#                            'KU035',
#                            'KU043',
#                            'KU046',
#                            'KU047',
#                            'KU049',
#                            'KU050',
#                            'KU051',
#                            'KU052',
#                            'KU060',
#                            'KU061',
#                            'KU062',
#                            'KU065',
#                            'KU069',
#                            'KU071',
#                            'KU072',
#                            'KU074',
#                            'KU075',
#                            'KU076',
#                            'KU077',
#                            'KU078',
#                            'KU079',
#                            'KU081',
#                            'KU082',
#                            'KU086',
#                            'KU111',
#                            'KU090',
#                            'KU091',
#                            'KU097',
#                            'KU098',
#                            'KU102',
#                            'KU103',
#                            'KU105',
#                            'KU106',
#                            'KU108',
#                            'KU109',
#                            'KU139',
#                            'KU140',
#                            'KU142',
#                            'KU143',
#                            'KU145',
#                            'KU146',
#                            'KU153',
#                            'KU148',
#                            'KU149',
#                            'KU151',
#                            'KU152',
#                            'KU165',
#                            'KU167',
#                            'KU169',
#                            'KU170',
#                            'KU171',
#                            'KU172',
#                            'KU176',
#                            'KU177',
#                            'KU178',
#                            'KU179',
#                            'KU181',
#                            'KU182',
#                            'KU186',
#                            'KU202',
#                            'KU204',
#                            'KU205',
#                            'KU208',
#                            'KU211',
#                            'KU213',
#                            'KU214',
#                            'KU216',
#                            'KU217',
#                            'KU218',
#                            'KU224',
#                            'KU226',
#                            'KU230',
#                            'KU231',
#                            'KU232',
#                            'KU233',
#                            'KU235',
#                            'KU236',
#                            'KU239',
#                            'KU240',
#                            'KU320',
#                            'KU241',
#                            'KU322',
#                            'KU244',
#                            'KU245',
#                            'KU249',
#                            'KU250',
#                            'KU256',
#                            'KU257',
#                            'KU260',
#                            'KU261',
#                            'KU263',
#                            'KU265',
#                            'KU271',
#                            'KU272',
#                            'KU273',
#                            'KU275',
#                            'KU276',
#                            'KU280',
#                            'KU284',
#                            'KU285',
#                            'KU286',
#                            'KU287',
#                            'KU288',
#                            'KU290',
#                            'KU291',
#                            'KU295',
#                            'KU297',
#                            'KU300',
#                            'KU301',
#                            'KU304',
#                            'KU305',
#                            'KU312',
#                            'KU316',
#                            'KU317',
#                            'KU318',
#                            'KU398',
#                            'KU399',
#                            'KU400',
#                            'KU407',
#                            'KU402',
#                            'KU403',
#                            'KU405',
#                            'KU408',
#                            'KU410',
#                            'KU416',
#                            'KU417',
#                            'KU418',
#                            'KU420',
#                            'KU421',
#                            'KU422',
#                            'KU423',
#                            'KU425',
#                            'KU426',
#                            'KU444',
#                            'KU430',
#                            'KU433',
#                            'KU434',
#                            'KU435',
#                            'KU436',
#                            'KU438',
#                            'KU440',
#                            'KU441',
#                            'KU475',
#                            'KU478',
#                            'KU480',
#                            'KU481',
#                            'KU483',
#                            'KU484',
#                            'KU489',
#                            'KU491',
#                            'KU494',
#                            'KU495',
#                            'KU498',
#                            'KU499',
#                            'KU500',
#                            'KU503',
#                            'KU504',
#                            'KU505',
#                            'KU508',
#                            'KU507',
#                            'KU529',
#                            'KU531',
#                            'KU535',
#                            'KU536',
#                            'KU538',
#                            'KU541',
#                            'KU543',
#                            'KU545',
#                            'KU560',
#                            'KU561',
#                            'KU562',
#                            'KU563',
#                            'KU564',
#                            'KU309',
#                            'KU576',
#                            'KU577',
#                            'KU578',
#                            'KU445',
#                            'KU580',
#                            'KU581',
#                            'KU599',
#                            'KU583',
#                            'KU854',
#                            'KU584',
#                            'KU588',
#                            'KU592',
#                            'KU593',
#                            'KU595',
#                            'KU598',
#                            'KU601',
#                            'KU604',
#                            'KU607',
#                            'KU608',
#                            'KU609',
#                            'KU611',
#                            'KU638',
#                            'KU614',
#                            'KU615',
#                            'KU616',
#                            'KU619',
#                            'KU620',
#                            'KU623',
#                            'KU624',
#                            'KU625',
#                            'KU626',
#                            'KU630',
#                            'KU631',
#                            'KU635',
#                            'KU636',
#                            'KU678',
#                            'KU710',
#                            'KU680',
#                            'KU681',
#                            'KU683',
#                            'KU684',
#                            'KU686',
#                            'KU687',
#                            'KU689',
#                            'KU691',
#                            'KU694',
#                            'KU697',
#                            'KU698',
#                            'KU700',
#                            'KU702',
#                            'KU704',
#                            'KU707',
#                            'KU729',
#                            'KU732',
#                            'KU734',
#                            'KU736',
#                            'KU790',
#                            'KU738',
#                            'KU739',
#                            'KU740',
#                            'KU742',
#                            'KU743',
#                            'KU746',
#                            'KU747',
#                            'KU748',
#                            'KU791',
#                            'KU749',
#                            'KU751',
#                            'KU753',
#                            'KU755',
#                            'KU758',
#                            'KU759',
#                            'KU761',
#                            'KU762',
#                            'KU765',
#                            'KU766',
#                            'KU768',
#                            'KU771',
#                            'KU777',
#                            'KU778',
#                            'KU781',
#                            'KU783',
#                            'KU831',
#                            'KU832',
#                            'KU833',
#                            'KU834',
#                            'KU837',
#                            'KU844',
#                            'KU845',
#                            'KU846',
#                            'KU848',
#                            'KU849',
#                            'KU850',
#                            'KU851',
#                            'KU853',
#                            'KU857',
#                            'KU858',
#                            'KU859',
#                            'KU886',
#                            'KU887',
#                            'KU889',
#                            'KU890',
#                            'KU892',
#                            'KU893',
#                            'KU895',
#                            'KU785',
#                            'KU905',
#                            'KU908',
#                            'KU092',
#                            'KU915',
#                            'KU918',
#                            'KU921',
#                            'KU922',
#                            'KU924',
#                            'KU925',
#                            'KU927',
#                            'KU931',
#                            'KU934',
#                            'KU935',
#                            'KU936',
#                            'KU941',
#                            'KU946',
#                            'KU976',
#                            'KU977',
#                            'KU980',
#                            'KU981',
#                            'KU989',
#                            'KU992',
#                            'MA1',
#                            'SA1',
#                            'SA2',
#                            'SA3',
#                            'SA4',
#                            'MK01',
#                            'MK02',
#                            'MK04',
#                            'MK05',
#                            'MK06',
#                            'MK07',
#                            'MK08',
#                            'MK09',
#                            'MK10',
#                            'MK11',
#                            'MK12',
#                            'MK13',
#                            'MK14',
#                            'MK15',
#                            'MK16',
#                            'MK17',
#                            'MK18',
#                            'MK19',
#                            'MA2',
#                            'SA5',
#                            'MK21',
#                            'HVA01',
#                            'HVA02',
#                            'HVA03',
#                            'HVA04',
#                            'HVA05',
#                            'HVA06',
#                            'HVA07',
#                            'HVA08',
#                            'HVA09',
#                            'HVA10',
#                            'HVA11',
#                            'HVA12',
#                            'HVA13',
#                            'HVA14',
#                            'HVA15',
#                            'HVA16',
#                            'HVA17',
#                            'HVA18',
#                            'HVA19',
#                            'HVA20',
#                            'HVA21',
#                            'HVA90',
#                            'HVA91',
#                            'SK011',
#                            'SK014',
#                            'SK015',
#                            'SK016',
#                            'SK021',
#                            'SK022',
#                            'SK023',
#                            'SK024',
#                            'SK025',
#                            'SK041',
#                            'SK043',
#                            'SK044',
#                            'SK051',
#                            'SK052',
#                            'SK053',
#                            'SK061',
#                            'SK063',
#                            'SK064',
#                            'SK068',
#                            'SK069',
#                            'SK071',
#                            'SK081',
#                            'SK082',
#                            'SK091',
#                            'SK093',
#                            'SK101',
#                            'SK103',
#                            'SK105',
#                            'SK111',
#                            'SK112',
#                            'SK113',
#                            'SK114',
#                            'SK115',
#                            'SK122',
#                            'SK124',
#                            'SK125',
#                            'SK131',
#                            'SK132',
#                            'SK133',
#                            'SK134',
#                            'SK135',
#                            'SK138',
#                            'SK141',
#                            'SK142',
#                            'SK144',
#                            'SK146',
#                            'SK152',
#                            'SK153',
#                            'SK154',
#                            'SK161',
#                            'SK162',
#                            'SK171',
#                            'SK173',
#                            'SK174',
#                            'SK175',
#                            'SK176',
#                            'SK177',
#                            'SK178',
#                            'SK181',
#                            'SK182',
#                            'SK191',
#                            'SK192',
#                            'SK193',
#                            'SK194',
#                            'SK196',
#                            'SK197',
#                            'SK211',
#                            'SK212',
#                            'SK213',
#                            'ELY01',
#                            'ELY02',
#                            'ELY03',
#                            'ELY04',
#                            'ELY05',
#                            'ELY06',
#                            'ELY07',
#                            'ELY08',
#                            'ELY09',
#                            'ELY10',
#                            'ELY11',
#                            'ELY12',
#                            'ELY13',
#                            'ELY14',
#                            'ELY15',
#                            'ELY16',
#                            'AVI1',
#                            'AVI2',
#                            'AVI3',
#                            'AVI4',
#                            'AVI5',
#                            'AVI6',
#                            'AVI7',
#                            'TK1',
#                            'TK2',
#                            'TK3',
#                            'SHP09',
#                            'SHP15',
#                            'SHP10',
#                            'SHP25',
#                            'SHP11',
#                            'SHP19',
#                            'SHP05',
#                            'SHP17',
#                            'SHP14',
#                            'SHP08',
#                            'SHP21',
#                            'SHP20',
#                            'SHP06',
#                            'SHP12',
#                            'SHP18',
#                            'SHP13',
#                            'SHP07',
#                            'SHP04',
#                            'SHP16',
#                            'SHP03',
#                            'SHP00',
#                            'VP01',
#                            'VP02',
#                            'VP03',
#                            'VP04',
#                            'VP06',
#                            'VP07',
#                            'VP08',
#                            'VP09',
#                            'VP10',
#                            'VP11',
#                            'VP12',
#                            'VP13',
#                            'VP05',
#                            'PL5500',
#                            'PL5530',
#                            'PL5560',
#                            'PL5590',
#                            'PL5620',
#                            'PL5650',
#                            'PL5680',
#                            'PL5710',
#                            'PL5740',
#                            'PL5770',
#                            'PL5800',
#                            'PL5830',
#                            'HO1',
#                            'HO2',
#                            'HO3',
#                            'HO4',
#                            'HO6',
#                            'KO706',
#                            'KO708',
#                            'KO713',
#                            'KO715',
#                            'KO717',
#                            'KO725',
#                            'KO726',
#                            'KO729',
#                            'KO730',
#                            'KO731',
#                            'KO736',
#                            'KO742',
#                            'KO747',
#                            'KO748',
#                            'KO750',
#                            'KO757',
#                            'KO758',
#                            'KO761',
#                            'KO764',
#                            'KO769',
#                            'FI1',
#                            'FI19',
#                            'FI193',
#                            'FI194',
#                            'FI195',
#                            'FI196',
#                            'FI197',
#                            'FI1B',
#                            'FI1B1',
#                            'FI1C',
#                            'FI1C1',
#                            'FI1C2',
#                            'FI1C3',
#                            'FI1C4',
#                            'FI1C5',
#                            'FI1D',
#                            'FI1D1',
#                            'FI1D2',
#                            'FI1D3',
#                            'FI1D5',
#                            'FI1D7',
#                            'FI1D8',
#                            'FI1D9',
#                            'FI2',
#                            'FI20',
#                            'FI200']},
#                {'code': 'Tiedot',
#                 'text': 'Tiedot',
#                 'valueTexts': ['Maapinta-ala, km2',
#                                'Väestöä, jolla tiedossa koordinaatit',
#                                'Väkiluku',
#                                'Keskiväkiluku',
#                                'Väestönlisäys',
#                                'Väestönlisäys, promillea keskiväkiluvusta',
#                                'Väkiluvun muutos edellisestä vuodesta, %',
#                                'Väkiluvun muutos viidessä vuodessa, %',
#                                'Miehiä',
#                                'Naisia',
#                                'Naisia 1 000 miestä kohti',
#                                'Alle 7-vuotiaita',
#                                'Alle 7-vuotiaita, %',
# ...
#                                '%',
#                                'Alueella olevia miesten työpaikkoja',
#                                'Alueella olevia naisten työpaikkoja',
#                                'Alkutuotannon työpaikkoja',
#                                'Alkutuotannon työpaikkojen osuus, %',
#                                'Jalostuksen työpaikkoja',
#                                'Jalostuksen työpaikkojen osuus, %',
#                                'Palvelujen työpaikkoja',
#                                'Palvelujen työpaikkojen osuus, %',
#                                'Toimialaltaan tuntemattomia työpaikkoja',
#                                'Toimialaltaan tuntemattomien työpaikkojen '
#                                'osuus, %',
#                                'Teollisuuden työpaikkoja',
#                                'Teollisuuden työpaikkojen osuus, %',
#                                'Teollisuuden työpaikkoja, miehet',
#                                'Teollisuuden työpaikkojen osuus kaikista '
#                                'miesten työpaikoista, %',
#                                'Teollisuuden työpaikkoja, naiset',
#                                'Teollisuuden työpaikkojen osuus kaikista '
#                                'naisten työpaikoista, %',
#                                'Rakentamisen työpaikkoja',
#                                'Rakentamisen työpaikkojen osuus, %',
#                                'Rakentamisen työpaikkoja, miehet',
#                                'Rakentamisen työpaikkojen osuus kaikista '
#                                'miesten työpaikoista, %',
#                                'Rakentamisen työpaikkoja, naiset',
#                                'Rakentamisen työpaikkojen osuus kaikista '
#                                'naisten työpaikoista, %',
#                                'Kaupan työpaikkoja',
#                                'Kaupan työpaikkojen osuus, %',
#                                'Kaupan työpaikkoja, miehet',
#                                'Kaupan työpaikkojen osuus kaikista miesten '
#                                'työpaikoista, %',
#                                'Kaupan työpaikkoja, naiset',
#                                'Kaupan työpaikkojen osuus kaikista naisten '
#                                'työpaikoista, %',
#                                'Majoitus- ja ravitsemistoiminnan työpaikkoja',
#                                'Majoitus- ja ravitsemistoiminnan työpaikkojen '
#                                'osuus, %',
#                                'Koulutuksen työpaikkoja',
#                                'Koulutuksen työpaikkojen osuus, %',
#                                'Koulutuksen työpaikkoja, miehet',
#                                'Koulutuksen työpaikkojen osuus kaikista '
#                                'miesten työpaikoista, %',
#                                'Koulutuksen työpaikkoja, naiset',
#                                'Koulutuksen työpaikkojen osuus kaikista '
#                                'naisten työpaikoista, %',
#                                'Terveys- ja sosiaalipalvelujen työpaikkoja',
#                                'Terveys- ja sosiaalipalvelujen työpaikkojen '
#                                'osuus, %',
#                                'Terveys- ja sosiaalipalvelujen työpaikkoja, '
#                                'miehet',
#                                'Terveys- ja sosiaalipalvelujen työpaikkojen '
#                                'osuus kaikista miesten työpaikoista, %',
#                                'Terveys- ja sosiaalipalvelujen työpaikkoja, '
#                                'naiset',
#                                'Terveys- ja sosiaalipalvelujen työpaikkojen '
#                                'osuus kaikista naisten työpaikoista, %',
#                                'Informaatiosektorin työpaikkoja',
#                                'Informaatiosektorin työpaikkojen osuus, %'],
#                 'values': ['M489',
#                            'M520',
#                            'M411',
#                            'M521',
#                            'M316',
#                            'M317',
#                            'M476',
#                            'M477',
#                            'M469',
#                            'M471',
#                            'M406',
#                            'M393',
#                            'M392',
#                            'M390',
#                            'M391',
#                            'M401',
#                            'M403',
#                            'M422',
#                            'M421',
#                            'M400',
#                            'M402',
#                            'M479',
#                            'M478',
#                            'M394',
#                            'M395',
#                            'M396',
#                            'M397',
#                            'M398',
#                            'M399',
#                            'M405',
#                            'M404',
#                            'M409',
#                            'M410',
#                            'M407',
#                            'M408',
#                            'M306',
#                            'M307',
#                            'M300',
#                            'M301',
#                            'M303',
#                            'M304',
#                            'M522',
#                            'M279',
#                            'M272',
#                            'M265',
#                            'M523',
#                            'M298',
#                            'M267',
#                            'M274',
#                            'M297',
#                            'M284',
#                            'M525',
#                            'M40',
#                            'M302',
#                            'M44',
#                            'M41',
#                            'M30',
#                            'M31',
#                            'M32',
#                            'M33',
#                            'M34',
#                            'M35',
#                            'M36',
#                            'M37',
#                            'M38',
#                            'M39',
#                            'M526',
#                            'M53',
#                            'M54',
#                            'M61',
#                            'M62',
#                            'M55',
#                            'M56',
#                            'M59',
#                            'M60',
#                            'M42',
#                            'M43',
#                            'M49',
#                            'M50',
#                            'M45',
#                            'M46',
#                            'M51',
#                            'M52',
#                            'M69',
#                            'M70',
#                            'M481',
#                            'M480',
#                            'M57',
#                            'M58',
#                            'M527',
#                            'M63',
#                            'M64',
#                            'M65',
#                            'M66',
#                            'M528',
#                            'M3',
#                            'M1',
#                            'M2',
#                            'M4',
#                            'M5',
#                            'M6',
#                            'M7',
#                            'M8',
#                            'M9',
#                            'M10',
#                            'M11',
#                            'M47',
#                            'M48',
#                            'M28',
#                            'M29',
#                            'M529',
#                            'M318',
#                            'M319',
#                            'M508',
#                            'M509',
#                            'M510',
#                            'M511',
#                            'M512',
#                            'M513',
#                            'M487',
#                            'M488',
#                            'M504',
#                            'M505',
#                            'M507',
#                            'M506',
#                            'M484',
#                            'M486',
#                            'M337',
#                            'M336',
#                            'M339',
#                            'M338',
#                            'M341',
#                            'M340',
#                            'M330',
#                            'M331',
#                            'M332',
#                            'M333',
#                            'M335',
#                            'M334',
#                            'M325',
#                            'M324',
#                            'M327',
#                            'M326',
#                            'M328',
#                            'M329',
#                            'M349',
#                            'M348',
#                            'M342',
#                            'M343',
#                            'M530',
#                            'M366',
#                            'M367',
#                            'M373',
#                            'M372',
#                            'M384',
#                            'M385',
#                            'M531',
#                            'M378',
#                            'M485',
#                            'M151',
#                            'M137',
#                            'M532',
#                            'M533',
#                            'M138',
#                            'M150',
#                            'M73',
#                            'M74',
#                            'M81',
#                            'M82',
#                            'M103',
#                            'M104',
#                            'M534',
#                            'M535',
#                            'M536',
#                            'M129',
#                            'M130',
#                            'M163',
#                            'M164',
#                            'M115',
#                            'M116',
#                            'M159',
#                            'M160',
#                            'M161',
#                            'M162',
#                            'M537',
#                            'M538',
#                            'M539',
#                            'M147',
#                            'M148',
#                            'M149',
#                            'M101',
#                            'M102',
#                            'M171',
#                            'M172',
#                            'M77',
#                            'M78',
#                            'M157',
#                            'M158',
#                            'M97',
#                            'M98',
#                            'M131',
#                            'M141',
#                            'M132',
#                            'M142',
#                            'M133',
#                            'M143',
#                            'M134',
#                            'M144',
#                            'M135',
#                            'M145',
#                            'M136',
#                            'M146',
#                            'M173',
#                            'M174',
#                            'M175',
#                            'M176',
#                            'M177',
#                            'M178',
#                            'M152',
#                            'M155',
#                            'M156',
#                            'M800',
#                            'M801',
#                            'M71',
#                            'M72',
#                            'M83',
#                            'M84',
#                            'M105',
#                            'M106',
#                            'M153',
#                            'M154',
#                            'M123',
#                            'M124',
#                            'M125',
#                            'M126',
#                            'M127',
#                            'M128',
#                            'M107',
#                            'M108',
#                            'M109',
#                            'M110',
#                            'M111',
#                            'M112',
#                            'M85',
#                            'M86',
#                            'M87',
#                            'M88',
#                            'M89',
#                            'M90',
#                            'M113',
#                            'M114',
#                            'M91',
#                            'M92',
#                            'M93',
#                            'M94',
#                            'M95',
#                            'M96',
#                            'M117',
#                            'M118',
#                            'M119',
#                            'M120',
#                            'M121',
#                            'M122',
#                            'M79',
#                            'M80']},
#                {'code': 'Vuosi',
#                 'text': 'Vuosi',
#                 'time': True,
#                 'valueTexts': ['1987',
#                                '1988',
#                                '1989',
#                                '1990',
#                                '1991',
#                                '1992',
#                                '1993',
#                                '1994',
#                                '1995',
#                                '1996',
#                                '1997',
#                                '1998',
#                                '1999',
#                                '2000',
#                                '2001',
#                                '2002',
#                                '2003',
#                                '2004',
#                                '2005',
#                                '2006',
#                                '2007',
#                                '2008',
#                                '2009',
#                                '2010',
#                                '2011',
#                                '2012',
#                                '2013',
#                                '2014',
#                                '2015',
#                                '2016',
#                                '2017',
#                                '2018',
#                                '2019',
#                                '2020',
#                                '2021',
#                                '2022',
#                                '2023'],
#                 'values': ['1987',
#                            '1988',
#                            '1989',
#                            '1990',
#                            '1991',
#                            '1992',
#                            '1993',
#                            '1994',
#                            '1995',
#                            '1996',
#                            '1997',
#                            '1998',
#                            '1999',
#                            '2000',
#                            '2001',
#                            '2002',
#                            '2003',
#                            '2004',
#                            '2005',
#                            '2006',
#                            '2007',
#                            '2008',
#                            '2009',
#                            '2010',
#                            '2011',
#                            '2012',
#                            '2013',
#                            '2014',
#                            '2015',
#                            '2016',
#                            '2017',
#                            '2018',
#                            '2019',
#                            '2020',
#                            '2021',
#                            '2022',
#                            '2023']}]}

# %% [markdown]
# ### - Choose id

# %%
# Choose index
idx = 5

endpoint.add_id(options[idx]['id'])
printer.print_chosen(options[idx]['id'], idx)

# %% [markdown]
# ### - Inspect endpoint

# %%
if endpoint.endpoint_found:
    data = pw.fetch(endpoint.get_current())
    printer.print_data(data)
else:
    options = pw.fetch(endpoint.get_current())
    printer.print_options(options)
